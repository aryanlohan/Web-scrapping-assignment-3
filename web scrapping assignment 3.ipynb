# %% [markdown]
# # Q4

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver = webdriver.Chrome('/Users/aryanlohan/downloads/chromedriver')
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(3)

cancle_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
serch_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
serch_bar.send_keys("smartphone")

srch_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
srch_btn.click()
time.sleep(5)

# %%
urls = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

brand_names = []
name = []
color = []
RAM = []
storage = []
prim_cam = []
sec_cam = []
Display_size = []
display_resolution = []
processor = []
processor_core = []
battery_cap = []
prices = []
product_url = []
for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
    try:
        bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
        battery_cap.append(bat_cap.text)
    except NoSuchElementException:
        battery_cap.append('-')
for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        brand_names.append(br_name.text.replace('Mobiles',''))
    except NoSuchElementException:
        brand_names.append('-')
    try:
        smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
        name.append(smt_name.text)
    except NoSuchElementException:
        name.append('-')
    try:
        clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    time.sleep(2)
    try:
        read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        pass
    time.sleep(3)
    try:
        disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
        Display_size.append(disp_size.text)
    except NoSuchElementException:
        Display_size.append
    try:
        disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
        display_resolution.append(disp_res.text)
    except NoSuchElementException:
        display_resolution.append('-')
    try:
        pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append('-')
    try:
        pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
        processor_core.append(pro_core.text)
    except NoSuchElementException:
        processor_core.append('-')
    try:
        rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
        storage.append(rom.text)
    except NoSuchElementException:
        storage.append('-')
    try:
        ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(2)
    
    try:
        p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
        prim_cam.append(p_cam.text)
    except NoSuchElementException:
        prim_cam.append('-')
    try:
        s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
        sec_cam.append(s_cam.text)
    except NoSuchElementException:
        sec_cam.append('-')
    

    try:
        price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        prices.append(price.text.replace('₹','Rs. '))
    except NoSuchElementException:
        prices.append('-')
    
data = list(zip(brand_names,name,color,RAM,storage,prim_cam,sec_cam,Display_size,display_resolution,processor,processor_core,battery_cap,prices,urls))
df = pd.DataFrame(data, columns = ["Brand Name","Smartphone Name","color","RAM","Storage/ROM","primary Camera","Secondary Camera","Display size","Display Resolution","Processor","Processor-core","Battery Capacity","Price","Product url"])

df.to_csv(r"C:\Users\Lenovo\Desktop\flipkart_smartphones.csv")
df
# Out:
#    Brand Name                                    Smartphone Name  \
# 0     realme      realme C11 2021 (Cool Grey, 32 GB)  (2 GB RAM)
# 1     realme      realme C11 2021 (Cool Grey, 64 GB)  (4 GB RAM)
# 2    SAMSUNG   SAMSUNG Galaxy F22 (Denim Blue, 64 GB)  (4 GB ...
# 3     realme      realme C11 2021 (Cool Blue, 64 GB)  (4 GB RAM)
# 4     realme          realme C31 (Dark Green, 32 GB)  (3 GB RAM)
# 5     realme        realme C31 (Light Silver, 32 GB)  (3 GB RAM)
# 6    SAMSUNG   SAMSUNG Galaxy F22 (Denim Black, 64 GB)  (4 GB...
# 7     realme          realme C31 (Dark Green, 64 GB)  (4 GB RAM)
# 8       POCO            POCO C31 (Royal Blue, 64 GB)  (4 GB RAM)
# 9       POCO            POCO C31 (Royal Blue, 32 GB)  (3 GB RAM)
# 10    realme          realme C21 (Cross Blue, 32 GB)  (3 GB RAM)
# 11    realme        realme C31 (Light Silver, 64 GB)  (4 GB RAM)
# 12    realme         realme C21 (Cross Black, 32 GB)  (3 GB RAM)
# 13   Infinix   Infinix HOT 12 Play (Daylight Green, 64 GB)  (...
# 14   Infinix   Infinix HOT 12 Play (Horizon Blue, 64 GB)  (4 ...
# 15   Infinix   Infinix HOT 12 Play (Racing Black, 64 GB)  (4 ...
# 16      POCO           POCO C31 (Shadow Gray, 64 GB)  (4 GB RAM)
# 17    realme      realme C11 2021 (Cool Blue, 32 GB)  (2 GB RAM)
# 18    realme           realme C20 (Cool Grey, 32 GB)  (2 GB RAM)
# 19    realme        realme 9 (Sunburst Gold, 128 GB)  (6 GB RAM)
# 20   Infinix   Infinix Hot 11 2022 (Sunset Gold, 64 GB)  (4 G...
# 21    realme       realme 9 (Stargaze White, 128 GB)  (6 GB RAM)
# 22    realme         realme C21Y (Cross Blue, 32 GB)  (3 GB RAM)
# 23    realme        realme C21Y (Cross Black, 32 GB)  (3 GB RAM)
#
#              color                 RAM Storage/ROM           primary Camera  \
# 0        Cool Grey                2 GB       32 GB          8MP Rear Camera
# 1        Cool Grey                4 GB       64 GB          8MP Rear Camera
# 2       Denim Blue                4 GB       64 GB   48MP + 8MP + 2MP + 2MP
# 3        Cool Blue                4 GB       64 GB          8MP Rear Camera
# 4       Dark Green                3 GB       32 GB       13MP + 2MP + 0.3MP
# 5     Light Silver                3 GB       32 GB       13MP + 2MP + 0.3MP
# 6      Denim Black                4 GB       64 GB   48MP + 8MP + 2MP + 2MP
# 7       Dark Green                4 GB       64 GB       13MP + 2MP + 0.3MP
# 8       Royal Blue                4 GB       64 GB         13MP + 2MP + 2MP
# 9       Royal Blue                3 GB       32 GB         13MP + 2MP + 2MP
# 10      Cross Blue                3 GB       32 GB         13MP + 2MP + 2MP
# 11    Light Silver                4 GB       64 GB       13MP + 2MP + 0.3MP
# 12     Cross Black                3 GB       32 GB         13MP + 2MP + 2MP
# 13  Daylight Green                4 GB       64 GB        13MP + Depth Lens
# 14    Horizon Blue                4 GB       64 GB        13MP + Depth Lens
# 15    Racing Black                4 GB       64 GB        13MP + Depth Lens
# 16     Shadow Gray                4 GB       64 GB         13MP + 2MP + 2MP
# 17       Cool Blue                2 GB       32 GB          8MP Rear Camera
# 18       Cool Grey  MediaTek Helio G35  Android 10                     2 GB
# 19   Sunburst Gold                6 GB      128 GB        108MP + 8MP + 2MP
# 20     Sunset Gold                4 GB       64 GB  13 MP + 2 MP Depth Lens
# 21  Stargaze White                6 GB      128 GB        108MP + 8MP + 2MP
# 22      Cross Blue                3 GB       32 GB         13MP + 2MP + 2MP
# 23     Cross Black                3 GB       32 GB         13MP + 2MP + 2MP
#
#      Secondary Camera                                       Display size  \
# 0    5MP Front Camera                                16.51 cm (6.5 inch)
# 1    5MP Front Camera                                16.51 cm (6.5 inch)
# 2   13MP Front Camera                                16.26 cm (6.4 inch)
# 3    5MP Front Camera                                16.51 cm (6.5 inch)
# 4    5MP Front Camera                               16.56 cm (6.52 inch)
# 5    5MP Front Camera                               16.56 cm (6.52 inch)
# 6   13MP Front Camera                                16.26 cm (6.4 inch)
# 7    5MP Front Camera                               16.56 cm (6.52 inch)
# 8    5MP Front Camera                               16.59 cm (6.53 inch)
# 9    5MP Front Camera                               16.59 cm (6.53 inch)
# 10   5MP Front Camera                                16.51 cm (6.5 inch)
# 11   5MP Front Camera                               16.56 cm (6.52 inch)
# 12   5MP Front Camera                                16.51 cm (6.5 inch)
# 13   8MP Front Camera                               17.32 cm (6.82 inch)
# 14   8MP Front Camera                               17.32 cm (6.82 inch)
# 15   8MP Front Camera                               17.32 cm (6.82 inch)
# 16   5MP Front Camera                               16.59 cm (6.53 inch)
# 17   5MP Front Camera                                16.51 cm (6.5 inch)
# 18     Dedicated Slot  Handset, Adapter (5V/2A), USB Cable, SIM Card ...
# 19  16MP Front Camera                                16.26 cm (6.4 inch)
# 20   8MP Front Camera                                17.02 cm (6.7 inch)
# 21  16MP Front Camera                                16.26 cm (6.4 inch)
# 22   5MP Front Camera                                16.51 cm (6.5 inch)
# 23   5MP Front Camera                                16.51 cm (6.5 inch)
#
#     Display Resolution                Processor Processor-core  \
# 0    1600 x 720 Pixels                Octa-core      Octa Core
# 1    1600 x 720 Pixels                Octa-core      Octa Core
# 2    1600 x 720 Pixels       MediaTek Helio G80      Octa Core
# 3    1600 x 720 Pixels                Octa-core      Octa Core
# 4    1600 x 720 Pixels              Unisoc T612      Octa Core
# 5    1600 x 720 Pixels              Unisoc T612      Octa Core
# 6    1600 x 720 Pixels       MediaTek Helio G80      Octa Core
# 7    1600 x 720 Pixels              Unisoc T612      Octa Core
# 8    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 9    1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 10   1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 11   1600 x 720 Pixels              Unisoc T612      Octa Core
# 12   1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 13   1640 x 720 Pixels              Unisoc T610      Octa Core
# 14   1640 x 720 Pixels              Unisoc T610      Octa Core
# 15   1640 x 720 Pixels              Unisoc T610      Octa Core
# 16   1600 x 720 Pixels       MediaTek Helio G35      Octa Core
# 17   1600 x 720 Pixels                Octa-core      Octa Core
# 18   RMX3063 / RMX3061        1600 x 720 Pixels            HD+
# 19  2400 x 1080 Pixels  Qualcomm Snapdragon 680      Octa Core
# 20  2400 x 1080 Pixels              UniSoc T610      Octa Core
# 21  2400 x 1080 Pixels  Qualcomm Snapdragon 680      Octa Core
# 22   1600 x 720 Pixels              Unisoc T610      Octa Core
# 23   1600 x 720 Pixels              Unisoc T610      Octa Core
#
#     Battery Capacity       Price  \
# 0   5000 mAh Battery   Rs. 7,499
# 1   5000 mAh Battery   Rs. 8,999
# 2   5000 mAh Battery  Rs. 10,499
# 3   5000 mAh Battery   Rs. 8,999
# 4   5000 mAh Battery   Rs. 9,299
# 5   5000 mAh Battery   Rs. 9,299
# 6   5000 mAh Battery  Rs. 10,499
# 7   5000 mAh Battery   Rs. 9,999
# 8   5000 mAh Battery   Rs. 9,999
# 9   5000 mAh Battery   Rs. 8,999
# 10  5000 mAh Battery   Rs. 9,999
# 11  5000 mAh Battery   Rs. 9,999
# 12  5000 mAh Battery   Rs. 9,999
# 13  5000 mAh Battery   Rs. 8,499
# 14  5000 mAh Battery   Rs. 8,499
# 15  5000 mAh Battery   Rs. 8,499
# 16  5000 mAh Battery   Rs. 9,999
# 17  5000 mAh Battery   Rs. 7,499
# 18  5000 mAh Battery   Rs. 7,999
# 19  5000 mAh Battery  Rs. 17,999
# 20  5000 mAh Battery   Rs. 8,999
# 21  5000 mAh Battery  Rs. 17,999
# 22  5000 mAh Battery   Rs. 9,999
# 23  5000 mAh Battery   Rs. 9,999
#
#                                           Product url
# 0   https://www.flipkart.com/realme-c11-2021-cool-...
# 1   https://www.flipkart.com/realme-c11-2021-cool-...
# 2   https://www.flipkart.com/samsung-galaxy-f22-de...
# 3   https://www.flipkart.com/realme-c11-2021-cool-...
# 4   https://www.flipkart.com/realme-c31-dark-green...
# 5   https://www.flipkart.com/realme-c31-light-silv...
# 6   https://www.flipkart.com/samsung-galaxy-f22-de...
# 7   https://www.flipkart.com/realme-c31-dark-green...
# 8   https://www.flipkart.com/poco-c31-royal-blue-6...
# 9   https://www.flipkart.com/poco-c31-royal-blue-3...
# 10  https://www.flipkart.com/realme-c21-cross-blue...
# 11  https://www.flipkart.com/realme-c31-light-silv...
# 12  https://www.flipkart.com/realme-c21-cross-blac...
# 13  https://www.flipkart.com/infinix-hot-12-play-d...
# 14  https://www.flipkart.com/infinix-hot-12-play-h...
# 15  https://www.flipkart.com/infinix-hot-12-play-r...
# 16  https://www.flipkart.com/poco-c31-shadow-gray-...
# 17  https://www.flipkart.com/realme-c11-2021-cool-...
# 18  https://www.flipkart.com/realme-c20-cool-grey-...
# 19  https://www.flipkart.com/realme-9-sunburst-gol...
# 20  https://www.flipkart.com/infinix-hot-11-2022-s...
# 21  https://www.flipkart.com/realme-9-stargaze-whi...
# 22  https://www.flipkart.com/realme-c21y-cross-blu...
# 23  https://www.flipkart.com/realme-c21y-cross-bla...

# %% [markdown]
# # Q6

# %%
driver=webdriver.Chrome('/Users/aryanlohan/downloads/chromedriver')
time.sleep(4)
url="https://trak.in/india-startup-funding-investment-2015/"
driver.get(url)  
time.sleep(4)

date=[]
s_name=[]
industry=[]
sub=[]
location=[]
i_name=[]
i_type=[]
amount=[]

for i in range(48,51):

    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        date.append(d.text)
    s=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for d in s:
        s_name.append(d.text)

    a=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for d in a:
        industry.append(d.text)

    su=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for d in su:
        sub.append(d.text)

    lo=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for d in lo:
        location.append(d.text)

    ina=driver.find_elements_by_xpath("//*[@id='tablepress-{}']/tbody/tr/td[7]".format(i))
    for d in ina:
        i_name.append(d.text)

    ty=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for d in ty:
        i_type.append(d.text)
 
    am=driver.find_elements_by_xpath('//*[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for d in am:
        amount.append(d.text)

time.sleep(2)

ans6=pd.DataFrame({})
ans6["Date"]=date
ans6["Startup_Name"]=s_name
ans6["Industry"]=industry
ans6["Sub"]=sub
ans6["Location"]=location
ans6["Investors name"]=i_name
ans6["Investment_type"]=i_type
ans6["Amount"]=amount
ans6
# Out:
#           Date               Startup_Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                                   Industry  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                                   Sub  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                        Investors name         Investment_type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#              Amount
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# # Q8

# %%
driver = webdriver.Chrome('/Users/aryanlohan/downloads/chromedriver')
url = "https://www.forbes.com/?sh=55783e032254"
driver.get(url)
time.sleep(3)

opt_btn = driver.find_element_by_xpath("//div[@class='header__left']//button").click()

blns = driver.find_elements_by_xpath("//li[@data-title='Billionaires']//a[1]")
bln = []
for i in blns[:1]:
    bln.append(i.get_attribute("href"))
     

for i in bln:
    driver.get(i)

bln_list = driver.find_element_by_xpath("//div[@class='channel-special-feature__articles-wrap']//a").click()
time.sleep(8)

rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass

names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass

net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass

Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')

citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')

source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')

industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
    
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
df
# Out:
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %% [markdown]
# # Q10

# %%
import selenium
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome('/Users/aryanlohan/downloads/chromedriver')
driver.get("https://www.hostelworld.com/s?q=London, England&country=England&city=London&type=city&id=3&from=2022-05-25&to=2022-05-28&guests=2&page=1")

title = []
distance = []
rating = []
total_review = []
prices = []
private_price = []
dorms_price = []
facilities=[]
prop_details=[]

title_tags = driver.find_elements_by_xpath("//h2[@class='title title-6']")
for i in title_tags:
    title.append(i.text)
    
distance_tags = driver.find_elements_by_xpath("//span[@class='description']")
for j in distance_tags:
    distance.append(j.text.split('-')[1])

rating_tags = driver.find_elements_by_xpath("//div[@class='score orange big']")
for k in rating_tags:
    rating.append(k.text)

total_review_tags = driver.find_elements_by_xpath("//div[@class='reviews']")
for l in total_review_tags:
    total_review.append(l.text)

    
P_prices_tags=driver.find_elements_by_xpath("//div[1][@class='price-col']") #locating web element of price
    
for n in P_prices_tags:
    private_price.append(n.text)


D_prices_tags=driver.find_elements_by_xpath("//div[2][@class='price-col']") #locating web element of price
  
for o in D_prices_tags:
    dorms_price.append(o.text)

faci_tags=driver.find_elements_by_xpath("//div[@class='facilities-label facilities']")    
for p in faci_tags:
    facilities.append(p.text)

prop_des=driver.find_elements_by_xpath("//div[@class='title-row']")    
for q in prop_des:
    prop_details.append(q.text)

# %%
df = pd.DataFrame({'Hostel Name':title[:5],'Distance':distance[:5],'Rating':rating[:5],'Total Review':total_review[:5],'Private Price':private_price[:5], 'Dorms Price':dorms_price[:5],'Property Details':prop_details[:5],'Facilities':facilities[:5]})
df
# Out:
#                      Hostel Name                 Distance Rating  \
# 0       St Christopher's Village   1.8km from city centre    8.1
# 1  Palmers Lodge - Swiss Cottage   6.5km from city centre    8.8
# 2                  Selina Camden   5.5km from city centre    8.5
# 3    Wombat's City Hostel London   3.6km from city centre    9.1
# 4               Generator London     3km from city centre    7.7
#
#           Total Review           Private Price                   Dorms Price  \
# 0  11398 Total Reviews   No Privates Available  Dorms From\nRs2458.94 Rs2213
# 1  15491 Total Reviews   No Privates Available            Dorms From\nRs1828
# 2     34 Total Reviews  Privates From\nRs25535  Dorms From\nRs8937.31 Rs7597
# 3  13871 Total Reviews  Privates From\nRs12365   Dorms From\nRs3527.2 Rs2645
# 4   7066 Total Reviews   Privates From\nRs8713            Dorms From\nRs2205
#
#                                     Property Details  \
# 0  St Christopher's Village\nHostel - 1.8km from ...
# 1  Palmers Lodge - Swiss Cottage\nHostel - 6.5km ...
# 2     Selina Camden\nHostel - 5.5km from city centre
# 3  St Christopher's Village\nHostel - 1.8km from ...
# 4  Palmers Lodge - Swiss Cottage\nHostel - 6.5km ...
#
#                                         Facilities
# 0  Free WiFi\nFollows Covid-19 sanitation guidance
# 1  Free WiFi\nFollows Covid-19 sanitation guidance
# 2                                        Free WiFi
# 3  Free WiFi\nFollows Covid-19 sanitation guidance
# 4  Free WiFi\nFollows Covid-19 sanitation guidance

# %% [markdown]
# # Q9

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
driver = webdriver.Chrome('/Users/aryanlohan/downloads/chromedriver')
driver.get("https://www.youtube.com/watch?v=TFr6G5zveS8")

# To scroll down
for _ in range(1000):
    driver.execute_script('window.scrollBy(0,5000)')
    
comment = []
vote = []
time = []

# Scrapping Comment
try:
    comment_tag = driver.find_elements_by_id('content-text')
    for i in comment_tag:
        comment.append(i.text)
except NoSuchElementException:
        comment.append("-")    

# Scrapping upvote
try:
    vote_tag = driver.find_elements_by_id("vote-count-middle")
    for j in vote_tag:
        vote.append(j.text)
except NoSuchElementException:
        vote.append("-")

#Scrapping time
try:   
    time_tag = driver.find_elements_by_xpath("//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
    for k in time_tag:
        time.append(k.text)
except NoSuchElementException:
        time.append("-")

# %%
df = pd.DataFrame({'Comments':comment[0:500], 'Upvote':vote[0:500], 'Time':time[17:517]})
df
# Out:
#                                               Comments Upvote  \
# 0    RIP Lata Mangeshkar Ji  Thank you for giving u...   8.4K
# 1    Just imagine this song was recorded 58 years b...    681
# 2    A message to the future generation."don't Let ...    477
# 3       58 years of this song still gives goosebumps ️     69
# 4    It's 2022 and already it's around 60 years of ...    155
# ..                                                 ...    ...
# 495  Bht hi heart touching lyrics hein or lata mada...      1
# 496  It's June 2022 let's see how many listening to...      1
# 497   Is song ko sunker mann kerta h ki sunti hi rahu       1
# 498                                       Old is gold       1
# 499  No Kissing, No Hugging, No Body Exposing, No E...    633
#
#                      Time
# 0
# 1
# 2
# 3
# 4
# ..                    ...
# 495           1 month ago
# 496          2 months ago
# 497          19 hours ago
# 498        44 minutes ago
# 499  2 weeks ago (edited)
#
# [500 rows x 3 columns]
